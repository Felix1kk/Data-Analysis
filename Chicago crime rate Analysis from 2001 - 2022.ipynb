# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
pd.set_option('display.max_column',80)
pd.set_option('display.max_row',80)

# %%
df=pd.read_csv('C:\\Users\personal\Downloads\Crimes_-_2001_to_Present.csv')
# Out:
# C:\Users\personal\AppData\Local\Temp\ipykernel_13628\1939736940.py:1: DtypeWarning: Columns (0,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('C:\\Users\personal\Downloads\Crimes_-_2001_to_Present.csv')

# %%
df.head()
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE  0870
# 2  11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE  0810
# 3  10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE  0560
#
#   Primary Type              Description Location Description Arrest Domestic  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE  False     True
# 1        THEFT           POCKET-PICKING              CTA BUS  False    False
# 2        THEFT                OVER $500            RESIDENCE  False     True
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK   True    False
# 4      ASSAULT                   SIMPLE            APARTMENT  False     True
#
# ...

# %%
df.describe()
# Out:
#                 Beat       District           Ward  Community Area  \
# count  717142.000000  717142.000000  716980.000000   716988.000000
# mean     1144.495774      11.216012      23.111600       36.876727
# std       694.890261       6.941574      14.006467       21.382482
# min       111.000000       1.000000       1.000000        1.000000
# 25%       612.000000       6.000000      10.000000       23.000000
# 50%      1024.000000      10.000000      24.000000       32.000000
# 75%      1712.000000      17.000000      34.000000       54.000000
# max      2535.000000      31.000000      50.000000       77.000000
#
#        X Coordinate  Y Coordinate           Year       Latitude      Longitude
# count  7.128140e+05  7.128140e+05  717142.000000  712814.000000  712814.000000
# mean   1.164695e+06  1.886332e+06    2016.398804      41.843690     -87.671138
# std    1.631749e+04  3.127122e+04       1.047383       0.086003       0.059381
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717147 entries, 0 to 717146
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    717147 non-null  object
#  1   Case Number           717143 non-null  object
#  2   Date                  717143 non-null  object
#  3   Block                 717143 non-null  object
#  4   IUCR                  717143 non-null  object
#  5   Primary Type          717143 non-null  object
#  6   Description           717142 non-null  object
#  7   Location Description  714899 non-null  object
#  8   Arrest                717142 non-null  object
#  9   Domestic              717142 non-null  object
#  10  Beat                  717142 non-null  float64
#  11  District              717142 non-null  float64
#  12  Ward                  716980 non-null  float64
#  13  Community Area        716988 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# ID                         0
# Case Number                4
# Date                       4
# Block                      4
# IUCR                       4
# Primary Type               4
# Description                5
# Location Description    2248
# Arrest                     5
# Domestic                   5
# Beat                       5
# District                   5
# Ward                     167
# Community Area           159
# FBI Code                   5
# X Coordinate            4333
# Y Coordinate            4333
# Year                       5
# Updated On                 5
# Latitude                4333
# Longitude               4333
# Location                4333
# dtype: int64

# %%
len(df)
# Out:
# 717147

# %%
df.shape
# Out:
# (717147, 22)

# %% [markdown]
# ##  Dropping null values

# %%
df=df.dropna(how='any')

# %%
df.isna().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %%
df.head(2)
# Out:
#          ID Case Number                    Date                Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM      043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM  008XX N CENTRAL AVE  0870
#
#   Primary Type              Description Location Description Arrest Domestic  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE  False     True
# 1        THEFT           POCKET-PICKING              CTA BUS  False    False
#
#      Beat  District  Ward  Community Area FBI Code  X Coordinate  \
# 0   924.0       9.0  12.0            61.0      08B     1165074.0
# 1  1511.0      15.0  29.0            25.0       06     1138875.0
#
#    Y Coordinate    Year              Updated On   Latitude  Longitude  \
# 0     1875917.0  2015.0  02/10/2018 03:50:01 PM  41.815117   -87.6700
# 1     1904869.0  2015.0  02/10/2018 03:50:01 PM  41.895080   -87.7654
#
#                         Location
# 0  (41.815117282, -87.669999562)
# ...

# %% [markdown]
# #  Converting Date column to date time

# %%
df.Date=pd.to_datetime(df.Date)
# Out:
# C:\Users\personal\AppData\Local\Temp\ipykernel_13628\1999132107.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Date=pd.to_datetime(df.Date)

# %%
df.head(2)
# Out:
#          ID Case Number                Date                Block  IUCR  \
# 0  10224738    HY411648 2015-09-05 13:30:00      043XX S WOOD ST  0486
# 1  10224739    HY411615 2015-09-04 11:30:00  008XX N CENTRAL AVE  0870
#
#   Primary Type              Description Location Description Arrest Domestic  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE  False     True
# 1        THEFT           POCKET-PICKING              CTA BUS  False    False
#
#      Beat  District  Ward  Community Area FBI Code  X Coordinate  \
# 0   924.0       9.0  12.0            61.0      08B     1165074.0
# 1  1511.0      15.0  29.0            25.0       06     1138875.0
#
#    Y Coordinate    Year              Updated On   Latitude  Longitude  \
# 0     1875917.0  2015.0  02/10/2018 03:50:01 PM  41.815117   -87.6700
# 1     1904869.0  2015.0  02/10/2018 03:50:01 PM  41.895080   -87.7654
#
#                         Location
# 0  (41.815117282, -87.669999562)
# 1  (41.895080471, -87.765400451)

# %%
df.sample(20)
# Out:
#               ID Case Number                Date                   Block  \
# 4554    10231411    HY419046 2015-09-10 22:00:00      027XX N HALSTED ST
# 242225  10616231    HZ369031 2016-07-29 00:16:00     071XX S LANGLEY AVE
# 389944  10767012    HZ532024 2016-11-27 11:55:00     013XX W CARROLL AVE
# 234739  10603993    HZ355999 2016-07-13 12:00:00     106XX S EMERALD AVE
# 282972  10685094    HZ438607 2016-09-17 18:42:00    008XX N MICHIGAN AVE
# 373258  10742840    HZ502892 2016-11-04 20:30:00     044XX S SHIELDS AVE
# 24139   10264065    HY451609 2015-10-06 11:15:00    102XX S PROSPECT AVE
# 212336  10331594    HY511935 2015-11-23 09:00:00    008XX S JEFFERSON ST
# 445596  10883282    JA193243 2017-03-19 23:35:00     076XX S STEWART AVE
# 652684  11216900    JB133269 2018-01-28 20:40:00        044XX N BROADWAY
# 684714  11261288    JB192642 2018-03-19 21:00:00  062XX S MARSHFIELD AVE
# 601592  11081081    JA423185 2017-09-08 00:01:00       036XX W BARRY AVE
# ...

# %%
df.tail(20)
# Out:
#               ID Case Number                Date  \
# 717122  11161569    JA528070 2017-11-27 21:00:00
# 717123  11161570    JA527960 2017-11-27 22:00:00
# 717124  11161571    JA528050 2017-11-27 22:30:00
# 717125  11161572    JA528065 2017-11-28 02:00:00
# 717126  11161573    JA528080 2017-11-16 16:40:00
# 717127  11161576    JA528052 2017-11-27 17:00:00
# 717128  11161577    JA527982 2017-11-28 08:37:00
# 717129  11161578    JA528092 2017-11-21 15:00:00
# 717130  11161579    JA527891 2017-11-27 14:30:00
# 717131  11161580    JA526641 2017-11-26 21:00:00
# 717132  11161584    JA528077 2017-11-28 09:50:00
# 717133  11161585    JA528062 2017-11-20 15:00:00
# 717134  11161586    JA528082 2017-11-27 21:00:00
# 717135  11161587    JA528091 2017-11-28 09:00:00
# 717136  11161589    JA528036 2017-10-05 15:00:00
# 717137  11161593    JA527996 2017-11-28 08:10:00
# 717138  11161594    JA528123 2017-11-28 10:00:00
# 717139  11161596    JA528030 2017-11-24 15:00:00
# ...

# %%
# %time df.ID=df.ID.astype(int)
# Out:
# CPU times: total: 312 ms
# Wall time: 1.14 s
# <timed exec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# %time df.ID.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 711018 entries, 0 to 717141
# Series name: ID
# Non-Null Count   Dtype
# --------------   -----
# 711018 non-null  int32
# dtypes: int32(1)
# memory usage: 8.1 MB
# CPU times: total: 62.5 ms
# Wall time: 204 ms

# %%
df.head()
# Out:
#          ID Case Number                Date                Block  IUCR  \
# 0  10224738    HY411648 2015-09-05 13:30:00      043XX S WOOD ST  0486
# 1  10224739    HY411615 2015-09-04 11:30:00  008XX N CENTRAL AVE  0870
# 3  10224740    HY411595 2015-09-05 12:45:00    035XX W BARRY AVE  2023
# 4  10224741    HY411610 2015-09-05 13:00:00  0000X N LARAMIE AVE  0560
# 5  10224742    HY411435 2015-09-05 10:55:00  082XX S LOOMIS BLVD  0610
#
#   Primary Type              Description Location Description Arrest Domestic  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE  False     True
# 1        THEFT           POCKET-PICKING              CTA BUS  False    False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK   True    False
# 4      ASSAULT                   SIMPLE            APARTMENT  False     True
# 5     BURGLARY           FORCIBLE ENTRY            RESIDENCE  False    False
#
#      Beat  District  Ward  Community Area FBI Code  X Coordinate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 711018 entries, 0 to 717141
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    711018 non-null  int32
#  1   Case Number           711018 non-null  object
#  2   Date                  711018 non-null  datetime64[ns]
#  3   Block                 711018 non-null  object
#  4   IUCR                  711018 non-null  object
#  5   Primary Type          711018 non-null  object
#  6   Description           711018 non-null  object
#  7   Location Description  711018 non-null  object
#  8   Arrest                711018 non-null  object
#  9   Domestic              711018 non-null  object
#  10  Beat                  711018 non-null  float64
#  11  District              711018 non-null  float64
#  12  Ward                  711018 non-null  float64
#  13  Community Area        711018 non-null  float64
# ...

# %% [markdown]
# #  extracting year from the date column

# %%
df.insert(3,'year',df.Date.dt.year)

# %%
df.head(2)
# Out:
#          ID Case Number                Date  year                Block  IUCR  \
# 0  10224738    HY411648 2015-09-05 13:30:00  2015      043XX S WOOD ST  0486
# 1  10224739    HY411615 2015-09-04 11:30:00  2015  008XX N CENTRAL AVE  0870
#
#   Primary Type              Description Location Description Arrest Domestic  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE  False     True
# 1        THEFT           POCKET-PICKING              CTA BUS  False    False
#
#      Beat  District  Ward  Community Area FBI Code  X Coordinate  \
# 0   924.0       9.0  12.0            61.0      08B     1165074.0
# 1  1511.0      15.0  29.0            25.0       06     1138875.0
#
#    Y Coordinate    Year              Updated On   Latitude  Longitude  \
# 0     1875917.0  2015.0  02/10/2018 03:50:01 PM  41.815117   -87.6700
# 1     1904869.0  2015.0  02/10/2018 03:50:01 PM  41.895080   -87.7654
#
#                         Location
# 0  (41.815117282, -87.669999562)
# ...

# %%
df.drop(columns=['Year'],inplace=True)
# Out:
# C:\Users\personal\AppData\Local\Temp\ipykernel_13628\376966497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Year'],inplace=True)

# %%
df.rename(columns={'year':'Year'},inplace=True)
# Out:
# C:\Users\personal\AppData\Local\Temp\ipykernel_13628\1481577869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'year':'Year'},inplace=True)

# %% [markdown]
# ###  extracting the month from the date

# %%
## Adding month name column

df.insert(4,'Month',df.Date.dt.month_name())

# %%
df.head(2)
# Out:
#          ID Case Number                Date  Year      Month  \
# 0  10224738    HY411648 2015-09-05 13:30:00  2015  September
# 1  10224739    HY411615 2015-09-04 11:30:00  2015  September
#
#                  Block  IUCR Primary Type              Description  \
# 0      043XX S WOOD ST  0486      BATTERY  DOMESTIC BATTERY SIMPLE
# 1  008XX N CENTRAL AVE  0870        THEFT           POCKET-PICKING
#
#   Location Description Arrest Domestic    Beat  District  Ward  \
# 0            RESIDENCE  False     True   924.0       9.0  12.0
# 1              CTA BUS  False    False  1511.0      15.0  29.0
#
#    Community Area FBI Code  X Coordinate  Y Coordinate  \
# 0            61.0      08B     1165074.0     1875917.0
# 1            25.0       06     1138875.0     1904869.0
#
#                Updated On   Latitude  Longitude                       Location
# 0  02/10/2018 03:50:01 PM  41.815117   -87.6700  (41.815117282, -87.669999562)
# ...

# %% [markdown]
# ###  extracting the hour from the date

# %%
df.insert(5,'Time_in_hrs',df.Date.dt.hour)

# %%
df.head(2)
# Out:
#          ID Case Number                Date  Year      Month  Time_in_hrs  \
# 0  10224738    HY411648 2015-09-05 13:30:00  2015  September           13
# 1  10224739    HY411615 2015-09-04 11:30:00  2015  September           11
#
#                  Block  IUCR Primary Type              Description  \
# 0      043XX S WOOD ST  0486      BATTERY  DOMESTIC BATTERY SIMPLE
# 1  008XX N CENTRAL AVE  0870        THEFT           POCKET-PICKING
#
#   Location Description Arrest Domestic    Beat  District  Ward  \
# 0            RESIDENCE  False     True   924.0       9.0  12.0
# 1              CTA BUS  False    False  1511.0      15.0  29.0
#
#    Community Area FBI Code  X Coordinate  Y Coordinate  \
# 0            61.0      08B     1165074.0     1875917.0
# 1            25.0       06     1138875.0     1904869.0
#
#                Updated On   Latitude  Longitude                       Location
# 0  02/10/2018 03:50:01 PM  41.815117   -87.6700  (41.815117282, -87.669999562)
# ...

# %% [markdown]
# ##  extracting the day name from the date

# %%
df.insert(6,'Day',df.Date.dt.day_name())

# %%
df.head()
# Out:
#          ID Case Number                Date  Year      Month  Time_in_hrs  \
# 0  10224738    HY411648 2015-09-05 13:30:00  2015  September           13
# 1  10224739    HY411615 2015-09-04 11:30:00  2015  September           11
# 3  10224740    HY411595 2015-09-05 12:45:00  2015  September           12
# 4  10224741    HY411610 2015-09-05 13:00:00  2015  September           13
# 5  10224742    HY411435 2015-09-05 10:55:00  2015  September           10
#
#         Day                Block  IUCR Primary Type              Description  \
# 0  Saturday      043XX S WOOD ST  0486      BATTERY  DOMESTIC BATTERY SIMPLE
# 1    Friday  008XX N CENTRAL AVE  0870        THEFT           POCKET-PICKING
# 3  Saturday    035XX W BARRY AVE  2023    NARCOTICS    POSS: HEROIN(BRN/TAN)
# 4  Saturday  0000X N LARAMIE AVE  0560      ASSAULT                   SIMPLE
# 5  Saturday  082XX S LOOMIS BLVD  0610     BURGLARY           FORCIBLE ENTRY
#
# ...

# %%
df.Year.unique()
# Out:
# array([2015, 2014, 2020, 2019, 2022, 2012, 2011, 2013, 2010, 2017, 2018,
#        2021, 2016, 2008, 2007, 2009, 2006, 2005, 2002], dtype=int64)

# %%
crime_type=df['Primary Type'].value_counts().head(10)

# %%
crime_type
# Out:
# THEFT                  164117
# BATTERY                132986
# CRIMINAL DAMAGE         81001
# ASSAULT                 49926
# OTHER OFFENSE           46994
# DECEPTIVE PRACTICE      45822
# NARCOTICS               37974
# BURGLARY                36696
# ROBBERY                 30587
# MOTOR VEHICLE THEFT     29702
# Name: Primary Type, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.title('Top 10 crimes in Chicago',fontsize=20)
sns.barplot(x=crime_type.index,y=crime_type)
plt.xticks(rotation=79)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('count for arrest made',fontsize=20)
sns.countplot(df.Arrest)
# Out:
# C:\Users\public\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'count for arrest made'}, xlabel='Arrest', ylabel='count'>

# %%
df.Time_in_hrs.value_counts()
# Out:
# 12    42191
# 18    41461
# 19    40501
# 15    38595
# 17    38533
# 20    38358
# 16    38107
# 21    36022
# 14    35927
# 22    35112
# 13    34582
# 0     33249
# 9     32726
# 11    32284
# 10    31463
# 23    29354
# 8     25156
# 1     21199
# 2     18360
# 7     17445
# 3     15311
# 6     12566
# 4     11981
# 5     10535
# Name: Time_in_hrs, dtype: int64

# %%
day=df.groupby('Time_in_hrs')

# %% [markdown]
# ###  Year with the highest crime rate

# %%
df.Year.value_counts().index
# Out:
# Int64Index([2016, 2017, 2015, 2018, 2019, 2020, 2021, 2014, 2022, 2013, 2012,
#             2011, 2010, 2008, 2009, 2007, 2006, 2005, 2002],
#            dtype='int64')

# %%
plt.figure(figsize=(15,6))
plt.title('Year with the highest amount of crime',fontsize=20)
sns.barplot(x=df.Year.value_counts().index, y=df.Year.value_counts())
plt.show()

# %%
df.head()
# Out:
#          ID Case Number                Date  Year      Month  Time_in_hrs  \
# 0  10224738    HY411648 2015-09-05 13:30:00  2015  September           13
# 1  10224739    HY411615 2015-09-04 11:30:00  2015  September           11
# 3  10224740    HY411595 2015-09-05 12:45:00  2015  September           12
# 4  10224741    HY411610 2015-09-05 13:00:00  2015  September           13
# 5  10224742    HY411435 2015-09-05 10:55:00  2015  September           10
#
#         Day                Block  IUCR Primary Type              Description  \
# 0  Saturday      043XX S WOOD ST  0486      BATTERY  DOMESTIC BATTERY SIMPLE
# 1    Friday  008XX N CENTRAL AVE  0870        THEFT           POCKET-PICKING
# 3  Saturday    035XX W BARRY AVE  2023    NARCOTICS    POSS: HEROIN(BRN/TAN)
# 4  Saturday  0000X N LARAMIE AVE  0560      ASSAULT                   SIMPLE
# 5  Saturday  082XX S LOOMIS BLVD  0610     BURGLARY           FORCIBLE ENTRY
#
# ...

# %%
df.Domestic.value_counts()
# Out:
# False    595434
# True     115584
# Name: Domestic, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.title('whether the crime occured domestically or not')
sns.barplot(x=df.Domestic.value_counts().index,y=df.Domestic.value_counts())
plt.show()

# %%
df['Location Description'].value_counts()
# Out:
# STREET                                   159214
# RESIDENCE                                120180
# APARTMENT                                 91888
# SIDEWALK                                  61877
# OTHER                                     28779
#                                           ...
# COLLEGE / UNIVERSITY - RESIDENCE HALL         1
# MOVIE HOUSE / THEATER                         1
# HORSE STABLE                                  1
# FARM                                          1
# SCHOOL - PRIVATE GROUNDS                      1
# Name: Location Description, Length: 137, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.title(' Top 10 Locations where crime occured the most',fontsize=20)
sns.barplot(x=df['Location Description'].value_counts().head(10).index, y=df['Location Description'].value_counts().head(10))
plt.xticks(rotation=79)
plt.show()

# %%
df.head()
# Out:
#          ID Case Number                Date  Year      Month  Time_in_hrs  \
# 0  10224738    HY411648 2015-09-05 13:30:00  2015  September           13
# 1  10224739    HY411615 2015-09-04 11:30:00  2015  September           11
# 3  10224740    HY411595 2015-09-05 12:45:00  2015  September           12
# 4  10224741    HY411610 2015-09-05 13:00:00  2015  September           13
# 5  10224742    HY411435 2015-09-05 10:55:00  2015  September           10
#
#         Day                Block  IUCR Primary Type              Description  \
# 0  Saturday      043XX S WOOD ST  0486      BATTERY  DOMESTIC BATTERY SIMPLE
# 1    Friday  008XX N CENTRAL AVE  0870        THEFT           POCKET-PICKING
# 3  Saturday    035XX W BARRY AVE  2023    NARCOTICS    POSS: HEROIN(BRN/TAN)
# 4  Saturday  0000X N LARAMIE AVE  0560      ASSAULT                   SIMPLE
# 5  Saturday  082XX S LOOMIS BLVD  0610     BURGLARY           FORCIBLE ENTRY
#
# ...

# %%
h=df.groupby('Time_in_hrs').count()

# %%
h
# Out:
#                 ID  Case Number   Date   Year  Month    Day  Block   IUCR  \
# Time_in_hrs
# 0            33249        33249  33249  33249  33249  33249  33249  33249
# 1            21199        21199  21199  21199  21199  21199  21199  21199
# 2            18360        18360  18360  18360  18360  18360  18360  18360
# 3            15311        15311  15311  15311  15311  15311  15311  15311
# 4            11981        11981  11981  11981  11981  11981  11981  11981
# 5            10535        10535  10535  10535  10535  10535  10535  10535
# 6            12566        12566  12566  12566  12566  12566  12566  12566
# 7            17445        17445  17445  17445  17445  17445  17445  17445
# 8            25156        25156  25156  25156  25156  25156  25156  25156
# 9            32726        32726  32726  32726  32726  32726  32726  32726
# 10           31463        31463  31463  31463  31463  31463  31463  31463
# ...

# %%
df.Time_in_hrs.count()
# Out:
# 711018

# %%
plt.figure(figsize=(15,6))
plt.plot(h.index, h['Primary Type'])
plt.title('time in which crimes occure the most',fontsize=20)
plt.xticks(np.arange(0,24))
plt.grid=True

# %%
df
# Out:
#               ID Case Number                Date  Year      Month  \
# 0       10224738    HY411648 2015-09-05 13:30:00  2015  September
# 1       10224739    HY411615 2015-09-04 11:30:00  2015  September
# 3       10224740    HY411595 2015-09-05 12:45:00  2015  September
# 4       10224741    HY411610 2015-09-05 13:00:00  2015  September
# 5       10224742    HY411435 2015-09-05 10:55:00  2015  September
# ...          ...         ...                 ...   ...        ...
# 717137  11161593    JA527996 2017-11-28 08:10:00  2017   November
# 717138  11161594    JA528123 2017-11-28 10:00:00  2017   November
# 717139  11161596    JA528030 2017-11-24 15:00:00  2017   November
# 717140  11161597    JA528012 2017-11-27 17:30:00  2017   November
# 717141  11161598    JA528076 2017-11-27 11:50:00  2017   November
#
#         Time_in_hrs       Day                 Block  IUCR     Primary Type  \
# 0                13  Saturday       043XX S WOOD ST  0486          BATTERY
# ...

# %%
test=df.groupby('Domestic')

# %%
plt.figure(figsize=(15,6))
plt.title(' Top 10 places where crime occured Domestically',fontsize=20)
test.get_group(True)['Location Description'].value_counts().head(10).plot(kind='bar')
plt.xticks(rotation=79)
plt.show()
